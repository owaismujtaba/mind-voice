# %%
from bids import BIDSLayout
from src.pipelines.p100_pipeline import P100AnalysisPipeline
from src.utils.logger import create_logger
from src.utils.data import load_yaml

# %%
config = 'config.yaml'
config = load_yaml(config)
logger = create_logger('plotting')

# %%
visual = {
        "label": "Visual",
        "trial_type": "Stimulus",
        "tmin": -0.2,
        "tmax": 0.5,
        "trial_mode": " ",
        "trial_unit": "Words",
        "experiment_mode": "Experiment",
        "trial_boundary": "Start",
        "modality": "Pictures"
    }
    

rest = {
        "label": "Rest",
        "trial_type": "Fixation",
        "tmin": -0.2,
        "tmax": 0.5,
        "trial_mode": " ",
        "trial_unit": "Words",
        "experiment_mode": "Experiment",
        "trial_boundary": "Start",
        "modality": "Pictures",
        "time_window": (0.08, 0.12)  # Optional window for P100
    }

# %%
layout = BIDSLayout('BIDS', validate=True)
subject_ids = layout.get_subjects()
visual_data = []
rest_data = []

for sub in subject_ids:
    session_ids = layout.get_sessions(subject=sub)  
    for ses in session_ids:
        print(sub, ses)
        pipeline = P100AnalysisPipeline(
                    subject_id=sub,
                    session_id=ses,
                    condition1_config=visual,
                    condition2_config=rest,
                    channels = ['PO3', 'POz', 'PO4'], 
                    logger=logger,
                    config = config
        )
        key = f'sub-{sub}_ses-{ses}'
        pipeline.run(get_data_only=True)
        selected_channels = ['PO3', 'POz', 'PO4']
        visual_epochs =  pipeline.epochs1.copy()
        epochs_selected = visual_epochs.copy().pick_channels(selected_channels)
        visual_data.append(epochs_selected.get_data())
        rest_epochs =  pipeline.epochs2.copy()
        epochs_selected = rest_epochs.copy().pick_channels(selected_channels)
        rest_data.append(epochs_selected.get_data())
# Out:
# [2025-11-11 14:09:45] [INFO] Running pipeline in data-only mode
# [2025-11-11 14:09:45] [INFO] Loading data for sub-01, ses-01
# [2025-11-11 14:09:45] [INFO] Initializing BIDSDatasetReader Class
# 01 01
# ╭─────────────────────────────────────────╮
# │ 🚀 Initializing BIDSDatasetReader Class │
# ╰─────────────────────────────────────────╯
# [2025-11-11 14:09:45] [INFO] Loading Processed EEG Data: sub-01 ses-01
#  Loading Processed EEG Data: sub-01 ses-01
# [2025-11-11 14:09:47] [INFO] Building epochs
# [2025-11-11 14:09:47] [INFO]  Creating epochs for condition: Visual
# ╭─────────────────────────────────────╮
# │  Initializing EEGEpochBuilder Class │
# ╰─────────────────────────────────────╯
#  Creating EPOCHS
#         Extraction Criteria
# ┏━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Parameter          ┃ Value      ┃
# ┣━━━━━━━━━━━━━━━━━━━━╋━━━━━━━━━━━━┫
# ┃ 🧪 Trial Mode      ┃            ┃
# ┃ 📏 Trial Unit      ┃ Words      ┃
# ┃ 🔗 Experiment Mode ┃ Experiment ┃
# ┃ 🎭 Trial Boundary  ┃ Start      ┃
# ┃ 🔬 Trial Type      ┃ Stimulus   ┃
# ┃ 📊 Modality        ┃ Pictures   ┃
# ┃ ⏱ Tmin             ┃ -0.2       ┃
# ┃ ⏳ Tmax            ┃ 0.5        ┃
# ┗━━━━━━━━━━━━━━━━━━━━┻━━━━━━━━━━━━┛
# Not setting metadata
# 24 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 24 events and 701 original time points ...
# 0 bad epochs dropped
# [2025-11-11 14:09:47] [INFO]  Creating epochs for condition: Rest
# ╭─────────────────────────────────────╮
# │  Initializing EEGEpochBuilder Class │
# ╰─────────────────────────────────────╯
#  Creating EPOCHS
#         Extraction Criteria
# ┏━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Parameter          ┃ Value      ┃
# ┣━━━━━━━━━━━━━━━━━━━━╋━━━━━━━━━━━━┫
# ┃ 🧪 Trial Mode      ┃            ┃
# ┃ 📏 Trial Unit      ┃ Words      ┃
# ┃ 🔗 Experiment Mode ┃ Experiment ┃
# ┃ 🎭 Trial Boundary  ┃ Start      ┃
# ┃ 🔬 Trial Type      ┃ Fixation   ┃
# ┃ 📊 Modality        ┃ Pictures   ┃
# ┃ ⏱ Tmin             ┃ -0.2       ┃
# ┃ ⏳ Tmax            ┃ 0.5        ┃
# ┗━━━━━━━━━━━━━━━━━━━━┻━━━━━━━━━━━━┛
# Not setting metadata
# 24 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 24 events and 701 original time points ...
# 0 bad epochs dropped
# [2025-11-11 14:09:47] [INFO]  Epochs 1: (24, 64, 701)
# [2025-11-11 14:09:47] [INFO]  Epochs 2: (24, 64, 701)
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# [2025-11-11 14:09:47] [INFO] Running pipeline in data-only mode
# [2025-11-11 14:09:47] [INFO] Loading data for sub-02, ses-01
# [2025-11-11 14:09:47] [INFO] Initializing BIDSDatasetReader Class
# 02 01
# ╭─────────────────────────────────────────╮
# │ 🚀 Initializing BIDSDatasetReader Class │
# ╰─────────────────────────────────────────╯
# [2025-11-11 14:09:47] [INFO] Loading Processed EEG Data: sub-02 ses-01
#  Loading Processed EEG Data: sub-02 ses-01
# [2025-11-11 14:09:49] [INFO] Building epochs
# [2025-11-11 14:09:49] [INFO]  Creating epochs for condition: Visual
# ╭─────────────────────────────────────╮
# │  Initializing EEGEpochBuilder Class │
# ╰─────────────────────────────────────╯
#  Creating EPOCHS
#         Extraction Criteria
# ┏━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Parameter          ┃ Value      ┃
# ┣━━━━━━━━━━━━━━━━━━━━╋━━━━━━━━━━━━┫
# ┃ 🧪 Trial Mode      ┃            ┃
# ┃ 📏 Trial Unit      ┃ Words      ┃
# ┃ 🔗 Experiment Mode ┃ Experiment ┃
# ┃ 🎭 Trial Boundary  ┃ Start      ┃
# ┃ 🔬 Trial Type      ┃ Stimulus   ┃
# ┃ 📊 Modality        ┃ Pictures   ┃
# ┃ ⏱ Tmin             ┃ -0.2       ┃
# ┃ ⏳ Tmax            ┃ 0.5        ┃
# ┗━━━━━━━━━━━━━━━━━━━━┻━━━━━━━━━━━━┛
# Not setting metadata
# 24 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 24 events and 701 original time points ...
# 0 bad epochs dropped
# [2025-11-11 14:09:49] [INFO]  Creating epochs for condition: Rest
# ╭─────────────────────────────────────╮
# │  Initializing EEGEpochBuilder Class │
# ╰─────────────────────────────────────╯
#  Creating EPOCHS
#         Extraction Criteria
# ┏━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Parameter          ┃ Value      ┃
# ┣━━━━━━━━━━━━━━━━━━━━╋━━━━━━━━━━━━┫
# ┃ 🧪 Trial Mode      ┃            ┃
# ┃ 📏 Trial Unit      ┃ Words      ┃
# ┃ 🔗 Experiment Mode ┃ Experiment ┃
# ┃ 🎭 Trial Boundary  ┃ Start      ┃
# ┃ 🔬 Trial Type      ┃ Fixation   ┃
# ┃ 📊 Modality        ┃ Pictures   ┃
# ┃ ⏱ Tmin             ┃ -0.2       ┃
# ┃ ⏳ Tmax            ┃ 0.5        ┃
# ┗━━━━━━━━━━━━━━━━━━━━┻━━━━━━━━━━━━┛
# Not setting metadata
# 24 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 24 events and 701 original time points ...
# 0 bad epochs dropped
# [2025-11-11 14:09:49] [INFO]  Epochs 1: (24, 64, 701)
# [2025-11-11 14:09:49] [INFO]  Epochs 2: (24, 64, 701)
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# [2025-11-11 14:09:49] [INFO] Running pipeline in data-only mode
# [2025-11-11 14:09:49] [INFO] Loading data for sub-03, ses-01
# [2025-11-11 14:09:49] [INFO] Initializing BIDSDatasetReader Class
# 03 01
# ╭─────────────────────────────────────────╮
# │ 🚀 Initializing BIDSDatasetReader Class │
# ╰─────────────────────────────────────────╯
# [2025-11-11 14:09:49] [INFO] Loading Processed EEG Data: sub-03 ses-01
#  Loading Processed EEG Data: sub-03 ses-01
# [2025-11-11 14:09:50] [INFO] Building epochs
# [2025-11-11 14:09:50] [INFO]  Creating epochs for condition: Visual
# ╭─────────────────────────────────────╮
# │  Initializing EEGEpochBuilder Class │
# ╰─────────────────────────────────────╯
#  Creating EPOCHS
#         Extraction Criteria
# ┏━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Parameter          ┃ Value      ┃
# ┣━━━━━━━━━━━━━━━━━━━━╋━━━━━━━━━━━━┫
# ┃ 🧪 Trial Mode      ┃            ┃
# ┃ 📏 Trial Unit      ┃ Words      ┃
# ┃ 🔗 Experiment Mode ┃ Experiment ┃
# ┃ 🎭 Trial Boundary  ┃ Start      ┃
# ┃ 🔬 Trial Type      ┃ Stimulus   ┃
# ┃ 📊 Modality        ┃ Pictures   ┃
# ┃ ⏱ Tmin             ┃ -0.2       ┃
# ┃ ⏳ Tmax            ┃ 0.5        ┃
# ┗━━━━━━━━━━━━━━━━━━━━┻━━━━━━━━━━━━┛
# Not setting metadata
# 24 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 24 events and 701 original time points ...
# 0 bad epochs dropped
# [2025-11-11 14:09:50] [INFO]  Creating epochs for condition: Rest
# ╭─────────────────────────────────────╮
# │  Initializing EEGEpochBuilder Class │
# ╰─────────────────────────────────────╯
#  Creating EPOCHS
#         Extraction Criteria
# ┏━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Parameter          ┃ Value      ┃
# ┣━━━━━━━━━━━━━━━━━━━━╋━━━━━━━━━━━━┫
# ┃ 🧪 Trial Mode      ┃            ┃
# ┃ 📏 Trial Unit      ┃ Words      ┃
# ┃ 🔗 Experiment Mode ┃ Experiment ┃
# ┃ 🎭 Trial Boundary  ┃ Start      ┃
# ┃ 🔬 Trial Type      ┃ Fixation   ┃
# ┃ 📊 Modality        ┃ Pictures   ┃
# ┃ ⏱ Tmin             ┃ -0.2       ┃
# ┃ ⏳ Tmax            ┃ 0.5        ┃
# ┗━━━━━━━━━━━━━━━━━━━━┻━━━━━━━━━━━━┛
# Not setting metadata
# 24 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 24 events and 701 original time points ...
# 0 bad epochs dropped
# [2025-11-11 14:09:50] [INFO]  Epochs 1: (24, 64, 701)
# [2025-11-11 14:09:50] [INFO]  Epochs 2: (24, 64, 701)
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# [2025-11-11 14:09:51] [INFO] Running pipeline in data-only mode
# [2025-11-11 14:09:51] [INFO] Loading data for sub-04, ses-01
# [2025-11-11 14:09:51] [INFO] Initializing BIDSDatasetReader Class
# 04 01
# ╭─────────────────────────────────────────╮
# │ 🚀 Initializing BIDSDatasetReader Class │
# ╰─────────────────────────────────────────╯
# [2025-11-11 14:09:51] [INFO] Loading Processed EEG Data: sub-04 ses-01
#  Loading Processed EEG Data: sub-04 ses-01
# [2025-11-11 14:09:52] [INFO] Building epochs
# [2025-11-11 14:09:52] [INFO]  Creating epochs for condition: Visual
# ╭─────────────────────────────────────╮
# │  Initializing EEGEpochBuilder Class │
# ╰─────────────────────────────────────╯
#  Creating EPOCHS
#         Extraction Criteria
# ┏━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Parameter          ┃ Value      ┃
# ┣━━━━━━━━━━━━━━━━━━━━╋━━━━━━━━━━━━┫
# ┃ 🧪 Trial Mode      ┃            ┃
# ┃ 📏 Trial Unit      ┃ Words      ┃
# ┃ 🔗 Experiment Mode ┃ Experiment ┃
# ┃ 🎭 Trial Boundary  ┃ Start      ┃
# ┃ 🔬 Trial Type      ┃ Stimulus   ┃
# ┃ 📊 Modality        ┃ Pictures   ┃
# ┃ ⏱ Tmin             ┃ -0.2       ┃
# ┃ ⏳ Tmax            ┃ 0.5        ┃
# ┗━━━━━━━━━━━━━━━━━━━━┻━━━━━━━━━━━━┛
# Not setting metadata
# 24 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 24 events and 701 original time points ...
# 0 bad epochs dropped
# [2025-11-11 14:09:52] [INFO]  Creating epochs for condition: Rest
# ╭─────────────────────────────────────╮
# │  Initializing EEGEpochBuilder Class │
# ╰─────────────────────────────────────╯
#  Creating EPOCHS
#         Extraction Criteria
# ┏━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Parameter          ┃ Value      ┃
# ┣━━━━━━━━━━━━━━━━━━━━╋━━━━━━━━━━━━┫
# ┃ 🧪 Trial Mode      ┃            ┃
# ┃ 📏 Trial Unit      ┃ Words      ┃
# ┃ 🔗 Experiment Mode ┃ Experiment ┃
# ┃ 🎭 Trial Boundary  ┃ Start      ┃
# ┃ 🔬 Trial Type      ┃ Fixation   ┃
# ┃ 📊 Modality        ┃ Pictures   ┃
# ┃ ⏱ Tmin             ┃ -0.2       ┃
# ┃ ⏳ Tmax            ┃ 0.5        ┃
# ┗━━━━━━━━━━━━━━━━━━━━┻━━━━━━━━━━━━┛
# Not setting metadata
# 24 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 24 events and 701 original time points ...
# 0 bad epochs dropped
# [2025-11-11 14:09:52] [INFO]  Epochs 1: (24, 64, 701)
# [2025-11-11 14:09:52] [INFO]  Epochs 2: (24, 64, 701)
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# [2025-11-11 14:09:53] [INFO] Running pipeline in data-only mode
# [2025-11-11 14:09:53] [INFO] Loading data for sub-04, ses-02
# [2025-11-11 14:09:53] [INFO] Initializing BIDSDatasetReader Class
# 04 02
# ╭─────────────────────────────────────────╮
# │ 🚀 Initializing BIDSDatasetReader Class │
# ╰─────────────────────────────────────────╯
# [2025-11-11 14:09:53] [INFO] Loading Processed EEG Data: sub-04 ses-02
#  Loading Processed EEG Data: sub-04 ses-02
# [2025-11-11 14:09:54] [INFO] Building epochs
# [2025-11-11 14:09:54] [INFO]  Creating epochs for condition: Visual
# ╭─────────────────────────────────────╮
# │  Initializing EEGEpochBuilder Class │
# ╰─────────────────────────────────────╯
#  Creating EPOCHS
#         Extraction Criteria
# ┏━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Parameter          ┃ Value      ┃
# ┣━━━━━━━━━━━━━━━━━━━━╋━━━━━━━━━━━━┫
# ┃ 🧪 Trial Mode      ┃            ┃
# ┃ 📏 Trial Unit      ┃ Words      ┃
# ┃ 🔗 Experiment Mode ┃ Experiment ┃
# ┃ 🎭 Trial Boundary  ┃ Start      ┃
# ┃ 🔬 Trial Type      ┃ Stimulus   ┃
# ┃ 📊 Modality        ┃ Pictures   ┃
# ┃ ⏱ Tmin             ┃ -0.2       ┃
# ┃ ⏳ Tmax            ┃ 0.5        ┃
# ┗━━━━━━━━━━━━━━━━━━━━┻━━━━━━━━━━━━┛
# Not setting metadata
# 24 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 24 events and 701 original time points ...
# 0 bad epochs dropped
# [2025-11-11 14:09:54] [INFO]  Creating epochs for condition: Rest
# ╭─────────────────────────────────────╮
# │  Initializing EEGEpochBuilder Class │
# ╰─────────────────────────────────────╯
#  Creating EPOCHS
#         Extraction Criteria
# ┏━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Parameter          ┃ Value      ┃
# ┣━━━━━━━━━━━━━━━━━━━━╋━━━━━━━━━━━━┫
# ┃ 🧪 Trial Mode      ┃            ┃
# ┃ 📏 Trial Unit      ┃ Words      ┃
# ┃ 🔗 Experiment Mode ┃ Experiment ┃
# ┃ 🎭 Trial Boundary  ┃ Start      ┃
# ┃ 🔬 Trial Type      ┃ Fixation   ┃
# ┃ 📊 Modality        ┃ Pictures   ┃
# ┃ ⏱ Tmin             ┃ -0.2       ┃
# ┃ ⏳ Tmax            ┃ 0.5        ┃
# ┗━━━━━━━━━━━━━━━━━━━━┻━━━━━━━━━━━━┛
# Not setting metadata
# 24 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 24 events and 701 original time points ...
# 0 bad epochs dropped
# [2025-11-11 14:09:54] [INFO]  Epochs 1: (24, 64, 701)
# [2025-11-11 14:09:54] [INFO]  Epochs 2: (24, 64, 701)
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# [2025-11-11 14:09:54] [INFO] Running pipeline in data-only mode
# [2025-11-11 14:09:54] [INFO] Loading data for sub-05, ses-01
# [2025-11-11 14:09:54] [INFO] Initializing BIDSDatasetReader Class
# 05 01
# ╭─────────────────────────────────────────╮
# │ 🚀 Initializing BIDSDatasetReader Class │
# ╰─────────────────────────────────────────╯
# [2025-11-11 14:09:54] [INFO] Loading Processed EEG Data: sub-05 ses-01
#  Loading Processed EEG Data: sub-05 ses-01
# [2025-11-11 14:09:55] [INFO] Building epochs
# [2025-11-11 14:09:55] [INFO]  Creating epochs for condition: Visual
# ╭─────────────────────────────────────╮
# │  Initializing EEGEpochBuilder Class │
# ╰─────────────────────────────────────╯
#  Creating EPOCHS
#         Extraction Criteria
# ┏━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Parameter          ┃ Value      ┃
# ┣━━━━━━━━━━━━━━━━━━━━╋━━━━━━━━━━━━┫
# ┃ 🧪 Trial Mode      ┃            ┃
# ┃ 📏 Trial Unit      ┃ Words      ┃
# ┃ 🔗 Experiment Mode ┃ Experiment ┃
# ┃ 🎭 Trial Boundary  ┃ Start      ┃
# ┃ 🔬 Trial Type      ┃ Stimulus   ┃
# ┃ 📊 Modality        ┃ Pictures   ┃
# ┃ ⏱ Tmin             ┃ -0.2       ┃
# ┃ ⏳ Tmax            ┃ 0.5        ┃
# ┗━━━━━━━━━━━━━━━━━━━━┻━━━━━━━━━━━━┛
# Not setting metadata
# 24 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 24 events and 701 original time points ...
# 0 bad epochs dropped
# [2025-11-11 14:09:56] [INFO]  Creating epochs for condition: Rest
# ╭─────────────────────────────────────╮
# │  Initializing EEGEpochBuilder Class │
# ╰─────────────────────────────────────╯
#  Creating EPOCHS
#         Extraction Criteria
# ┏━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Parameter          ┃ Value      ┃
# ┣━━━━━━━━━━━━━━━━━━━━╋━━━━━━━━━━━━┫
# ┃ 🧪 Trial Mode      ┃            ┃
# ┃ 📏 Trial Unit      ┃ Words      ┃
# ┃ 🔗 Experiment Mode ┃ Experiment ┃
# ┃ 🎭 Trial Boundary  ┃ Start      ┃
# ┃ 🔬 Trial Type      ┃ Fixation   ┃
# ┃ 📊 Modality        ┃ Pictures   ┃
# ┃ ⏱ Tmin             ┃ -0.2       ┃
# ┃ ⏳ Tmax            ┃ 0.5        ┃
# ┗━━━━━━━━━━━━━━━━━━━━┻━━━━━━━━━━━━┛
# Not setting metadata
# 24 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 24 events and 701 original time points ...
# 0 bad epochs dropped
# [2025-11-11 14:09:56] [INFO]  Epochs 1: (24, 64, 701)
# [2025-11-11 14:09:56] [INFO]  Epochs 2: (24, 64, 701)
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# [2025-11-11 14:09:56] [INFO] Running pipeline in data-only mode
# [2025-11-11 14:09:56] [INFO] Loading data for sub-05, ses-02
# [2025-11-11 14:09:56] [INFO] Initializing BIDSDatasetReader Class
# 05 02
# ╭─────────────────────────────────────────╮
# │ 🚀 Initializing BIDSDatasetReader Class │
# ╰─────────────────────────────────────────╯
# [2025-11-11 14:09:56] [INFO] Loading Processed EEG Data: sub-05 ses-02
#  Loading Processed EEG Data: sub-05 ses-02
# [2025-11-11 14:09:57] [INFO] Building epochs
# [2025-11-11 14:09:57] [INFO]  Creating epochs for condition: Visual
# ╭─────────────────────────────────────╮
# │  Initializing EEGEpochBuilder Class │
# ╰─────────────────────────────────────╯
#  Creating EPOCHS
#         Extraction Criteria
# ┏━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Parameter          ┃ Value      ┃
# ┣━━━━━━━━━━━━━━━━━━━━╋━━━━━━━━━━━━┫
# ┃ 🧪 Trial Mode      ┃            ┃
# ┃ 📏 Trial Unit      ┃ Words      ┃
# ┃ 🔗 Experiment Mode ┃ Experiment ┃
# ┃ 🎭 Trial Boundary  ┃ Start      ┃
# ┃ 🔬 Trial Type      ┃ Stimulus   ┃
# ┃ 📊 Modality        ┃ Pictures   ┃
# ┃ ⏱ Tmin             ┃ -0.2       ┃
# ┃ ⏳ Tmax            ┃ 0.5        ┃
# ┗━━━━━━━━━━━━━━━━━━━━┻━━━━━━━━━━━━┛
# Not setting metadata
# 24 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 24 events and 701 original time points ...
# 0 bad epochs dropped
# [2025-11-11 14:09:57] [INFO]  Creating epochs for condition: Rest
# ╭─────────────────────────────────────╮
# │  Initializing EEGEpochBuilder Class │
# ╰─────────────────────────────────────╯
#  Creating EPOCHS
#         Extraction Criteria
# ┏━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Parameter          ┃ Value      ┃
# ┣━━━━━━━━━━━━━━━━━━━━╋━━━━━━━━━━━━┫
# ┃ 🧪 Trial Mode      ┃            ┃
# ┃ 📏 Trial Unit      ┃ Words      ┃
# ┃ 🔗 Experiment Mode ┃ Experiment ┃
# ┃ 🎭 Trial Boundary  ┃ Start      ┃
# ┃ 🔬 Trial Type      ┃ Fixation   ┃
# ┃ 📊 Modality        ┃ Pictures   ┃
# ┃ ⏱ Tmin             ┃ -0.2       ┃
# ┃ ⏳ Tmax            ┃ 0.5        ┃
# ┗━━━━━━━━━━━━━━━━━━━━┻━━━━━━━━━━━━┛
# Not setting metadata
# 24 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 24 events and 701 original time points ...
# 0 bad epochs dropped
# [2025-11-11 14:09:57] [INFO]  Epochs 1: (24, 64, 701)
# [2025-11-11 14:09:57] [INFO]  Epochs 2: (24, 64, 701)
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 06 01
# [2025-11-11 14:09:58] [INFO] Running pipeline in data-only mode
# [2025-11-11 14:09:58] [INFO] Loading data for sub-06, ses-01
# [2025-11-11 14:09:58] [INFO] Initializing BIDSDatasetReader Class
# ╭─────────────────────────────────────────╮
# │ 🚀 Initializing BIDSDatasetReader Class │
# ╰─────────────────────────────────────────╯
# [2025-11-11 14:09:58] [INFO] Loading Processed EEG Data: sub-06 ses-01
#  Loading Processed EEG Data: sub-06 ses-01
# [2025-11-11 14:09:59] [INFO] Building epochs
# [2025-11-11 14:09:59] [INFO]  Creating epochs for condition: Visual
# ╭─────────────────────────────────────╮
# │  Initializing EEGEpochBuilder Class │
# ╰─────────────────────────────────────╯
#  Creating EPOCHS
#         Extraction Criteria
# ┏━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Parameter          ┃ Value      ┃
# ┣━━━━━━━━━━━━━━━━━━━━╋━━━━━━━━━━━━┫
# ┃ 🧪 Trial Mode      ┃            ┃
# ┃ 📏 Trial Unit      ┃ Words      ┃
# ┃ 🔗 Experiment Mode ┃ Experiment ┃
# ┃ 🎭 Trial Boundary  ┃ Start      ┃
# ┃ 🔬 Trial Type      ┃ Stimulus   ┃
# ┃ 📊 Modality        ┃ Pictures   ┃
# ┃ ⏱ Tmin             ┃ -0.2       ┃
# ┃ ⏳ Tmax            ┃ 0.5        ┃
# ┗━━━━━━━━━━━━━━━━━━━━┻━━━━━━━━━━━━┛
# Not setting metadata
# 24 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 24 events and 701 original time points ...
# 0 bad epochs dropped
# [2025-11-11 14:09:59] [INFO]  Creating epochs for condition: Rest
# ╭─────────────────────────────────────╮
# │  Initializing EEGEpochBuilder Class │
# ╰─────────────────────────────────────╯
#  Creating EPOCHS
#         Extraction Criteria
# ┏━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Parameter          ┃ Value      ┃
# ┣━━━━━━━━━━━━━━━━━━━━╋━━━━━━━━━━━━┫
# ┃ 🧪 Trial Mode      ┃            ┃
# ┃ 📏 Trial Unit      ┃ Words      ┃
# ┃ 🔗 Experiment Mode ┃ Experiment ┃
# ┃ 🎭 Trial Boundary  ┃ Start      ┃
# ┃ 🔬 Trial Type      ┃ Fixation   ┃
# ┃ 📊 Modality        ┃ Pictures   ┃
# ┃ ⏱ Tmin             ┃ -0.2       ┃
# ┃ ⏳ Tmax            ┃ 0.5        ┃
# ┗━━━━━━━━━━━━━━━━━━━━┻━━━━━━━━━━━━┛
# Not setting metadata
# 24 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 24 events and 701 original time points ...
# 0 bad epochs dropped
# [2025-11-11 14:09:59] [INFO]  Epochs 1: (24, 64, 701)
# [2025-11-11 14:09:59] [INFO]  Epochs 2: (24, 64, 701)
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# [2025-11-11 14:09:59] [INFO] Running pipeline in data-only mode
# [2025-11-11 14:09:59] [INFO] Loading data for sub-06, ses-02
# [2025-11-11 14:09:59] [INFO] Initializing BIDSDatasetReader Class
# 06 02
# ╭─────────────────────────────────────────╮
# │ 🚀 Initializing BIDSDatasetReader Class │
# ╰─────────────────────────────────────────╯
# [2025-11-11 14:09:59] [INFO] Loading Processed EEG Data: sub-06 ses-02
#  Loading Processed EEG Data: sub-06 ses-02
# [2025-11-11 14:10:01] [INFO] Building epochs
# [2025-11-11 14:10:01] [INFO]  Creating epochs for condition: Visual
# ╭─────────────────────────────────────╮
# │  Initializing EEGEpochBuilder Class │
# ╰─────────────────────────────────────╯
#  Creating EPOCHS
#         Extraction Criteria
# ┏━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Parameter          ┃ Value      ┃
# ┣━━━━━━━━━━━━━━━━━━━━╋━━━━━━━━━━━━┫
# ┃ 🧪 Trial Mode      ┃            ┃
# ┃ 📏 Trial Unit      ┃ Words      ┃
# ┃ 🔗 Experiment Mode ┃ Experiment ┃
# ┃ 🎭 Trial Boundary  ┃ Start      ┃
# ┃ 🔬 Trial Type      ┃ Stimulus   ┃
# ┃ 📊 Modality        ┃ Pictures   ┃
# ┃ ⏱ Tmin             ┃ -0.2       ┃
# ┃ ⏳ Tmax            ┃ 0.5        ┃
# ┗━━━━━━━━━━━━━━━━━━━━┻━━━━━━━━━━━━┛
# Not setting metadata
# 24 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 24 events and 701 original time points ...
# 0 bad epochs dropped
# [2025-11-11 14:10:01] [INFO]  Creating epochs for condition: Rest
# ╭─────────────────────────────────────╮
# │  Initializing EEGEpochBuilder Class │
# ╰─────────────────────────────────────╯
#  Creating EPOCHS
#         Extraction Criteria
# ┏━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Parameter          ┃ Value      ┃
# ┣━━━━━━━━━━━━━━━━━━━━╋━━━━━━━━━━━━┫
# ┃ 🧪 Trial Mode      ┃            ┃
# ┃ 📏 Trial Unit      ┃ Words      ┃
# ┃ 🔗 Experiment Mode ┃ Experiment ┃
# ┃ 🎭 Trial Boundary  ┃ Start      ┃
# ┃ 🔬 Trial Type      ┃ Fixation   ┃
# ┃ 📊 Modality        ┃ Pictures   ┃
# ┃ ⏱ Tmin             ┃ -0.2       ┃
# ┃ ⏳ Tmax            ┃ 0.5        ┃
# ┗━━━━━━━━━━━━━━━━━━━━┻━━━━━━━━━━━━┛
# Not setting metadata
# 24 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 24 events and 701 original time points ...
# 0 bad epochs dropped
# [2025-11-11 14:10:01] [INFO]  Epochs 1: (24, 64, 701)
# [2025-11-11 14:10:01] [INFO]  Epochs 2: (24, 64, 701)
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# [2025-11-11 14:10:01] [INFO] Running pipeline in data-only mode
# [2025-11-11 14:10:01] [INFO] Loading data for sub-07, ses-01
# [2025-11-11 14:10:01] [INFO] Initializing BIDSDatasetReader Class
# 07 01
# ╭─────────────────────────────────────────╮
# │ 🚀 Initializing BIDSDatasetReader Class │
# ╰─────────────────────────────────────────╯
# [2025-11-11 14:10:01] [INFO] Loading Processed EEG Data: sub-07 ses-01
#  Loading Processed EEG Data: sub-07 ses-01
# [2025-11-11 14:10:02] [INFO] Building epochs
# [2025-11-11 14:10:02] [INFO]  Creating epochs for condition: Visual
# ╭─────────────────────────────────────╮
# │  Initializing EEGEpochBuilder Class │
# ╰─────────────────────────────────────╯
#  Creating EPOCHS
#         Extraction Criteria
# ┏━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Parameter          ┃ Value      ┃
# ┣━━━━━━━━━━━━━━━━━━━━╋━━━━━━━━━━━━┫
# ┃ 🧪 Trial Mode      ┃            ┃
# ┃ 📏 Trial Unit      ┃ Words      ┃
# ┃ 🔗 Experiment Mode ┃ Experiment ┃
# ┃ 🎭 Trial Boundary  ┃ Start      ┃
# ┃ 🔬 Trial Type      ┃ Stimulus   ┃
# ┃ 📊 Modality        ┃ Pictures   ┃
# ┃ ⏱ Tmin             ┃ -0.2       ┃
# ┃ ⏳ Tmax            ┃ 0.5        ┃
# ┗━━━━━━━━━━━━━━━━━━━━┻━━━━━━━━━━━━┛
# Not setting metadata
# 24 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 24 events and 701 original time points ...
# 0 bad epochs dropped
# [2025-11-11 14:10:02] [INFO]  Creating epochs for condition: Rest
# ╭─────────────────────────────────────╮
# │  Initializing EEGEpochBuilder Class │
# ╰─────────────────────────────────────╯
#  Creating EPOCHS
#         Extraction Criteria
# ┏━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Parameter          ┃ Value      ┃
# ┣━━━━━━━━━━━━━━━━━━━━╋━━━━━━━━━━━━┫
# ┃ 🧪 Trial Mode      ┃            ┃
# ┃ 📏 Trial Unit      ┃ Words      ┃
# ┃ 🔗 Experiment Mode ┃ Experiment ┃
# ┃ 🎭 Trial Boundary  ┃ Start      ┃
# ┃ 🔬 Trial Type      ┃ Fixation   ┃
# ┃ 📊 Modality        ┃ Pictures   ┃
# ┃ ⏱ Tmin             ┃ -0.2       ┃
# ┃ ⏳ Tmax            ┃ 0.5        ┃
# ┗━━━━━━━━━━━━━━━━━━━━┻━━━━━━━━━━━━┛
# Not setting metadata
# 24 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 24 events and 701 original time points ...
# 0 bad epochs dropped
# [2025-11-11 14:10:03] [INFO]  Epochs 1: (24, 64, 701)
# [2025-11-11 14:10:03] [INFO]  Epochs 2: (24, 64, 701)
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 08 01
# [2025-11-11 14:10:03] [INFO] Running pipeline in data-only mode
# [2025-11-11 14:10:03] [INFO] Loading data for sub-08, ses-01
# [2025-11-11 14:10:03] [INFO] Initializing BIDSDatasetReader Class
# ╭─────────────────────────────────────────╮
# │ 🚀 Initializing BIDSDatasetReader Class │
# ╰─────────────────────────────────────────╯
# [2025-11-11 14:10:03] [INFO] Loading Processed EEG Data: sub-08 ses-01
#  Loading Processed EEG Data: sub-08 ses-01
# [2025-11-11 14:10:04] [INFO] Building epochs
# [2025-11-11 14:10:04] [INFO]  Creating epochs for condition: Visual
# ╭─────────────────────────────────────╮
# │  Initializing EEGEpochBuilder Class │
# ╰─────────────────────────────────────╯
#  Creating EPOCHS
#         Extraction Criteria
# ┏━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Parameter          ┃ Value      ┃
# ┣━━━━━━━━━━━━━━━━━━━━╋━━━━━━━━━━━━┫
# ┃ 🧪 Trial Mode      ┃            ┃
# ┃ 📏 Trial Unit      ┃ Words      ┃
# ┃ 🔗 Experiment Mode ┃ Experiment ┃
# ┃ 🎭 Trial Boundary  ┃ Start      ┃
# ┃ 🔬 Trial Type      ┃ Stimulus   ┃
# ┃ 📊 Modality        ┃ Pictures   ┃
# ┃ ⏱ Tmin             ┃ -0.2       ┃
# ┃ ⏳ Tmax            ┃ 0.5        ┃
# ┗━━━━━━━━━━━━━━━━━━━━┻━━━━━━━━━━━━┛
# Not setting metadata
# 24 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 24 events and 701 original time points ...
# 0 bad epochs dropped
# [2025-11-11 14:10:04] [INFO]  Creating epochs for condition: Rest
# ╭─────────────────────────────────────╮
# │  Initializing EEGEpochBuilder Class │
# ╰─────────────────────────────────────╯
#  Creating EPOCHS
#         Extraction Criteria
# ┏━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Parameter          ┃ Value      ┃
# ┣━━━━━━━━━━━━━━━━━━━━╋━━━━━━━━━━━━┫
# ┃ 🧪 Trial Mode      ┃            ┃
# ┃ 📏 Trial Unit      ┃ Words      ┃
# ┃ 🔗 Experiment Mode ┃ Experiment ┃
# ┃ 🎭 Trial Boundary  ┃ Start      ┃
# ┃ 🔬 Trial Type      ┃ Fixation   ┃
# ┃ 📊 Modality        ┃ Pictures   ┃
# ┃ ⏱ Tmin             ┃ -0.2       ┃
# ┃ ⏳ Tmax            ┃ 0.5        ┃
# ┗━━━━━━━━━━━━━━━━━━━━┻━━━━━━━━━━━━┛
# Not setting metadata
# 24 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 24 events and 701 original time points ...
# 0 bad epochs dropped
# [2025-11-11 14:10:04] [INFO]  Epochs 1: (24, 64, 701)
# [2025-11-11 14:10:04] [INFO]  Epochs 2: (24, 64, 701)
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# [2025-11-11 14:10:04] [INFO] Running pipeline in data-only mode
# [2025-11-11 14:10:04] [INFO] Loading data for sub-09, ses-01
# [2025-11-11 14:10:04] [INFO] Initializing BIDSDatasetReader Class
# 09 01
# ╭─────────────────────────────────────────╮
# │ 🚀 Initializing BIDSDatasetReader Class │
# ╰─────────────────────────────────────────╯
# [2025-11-11 14:10:04] [INFO] Loading Processed EEG Data: sub-09 ses-01
#  Loading Processed EEG Data: sub-09 ses-01
# [2025-11-11 14:10:06] [INFO] Building epochs
# [2025-11-11 14:10:06] [INFO]  Creating epochs for condition: Visual
# ╭─────────────────────────────────────╮
# │  Initializing EEGEpochBuilder Class │
# ╰─────────────────────────────────────╯
#  Creating EPOCHS
#         Extraction Criteria
# ┏━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Parameter          ┃ Value      ┃
# ┣━━━━━━━━━━━━━━━━━━━━╋━━━━━━━━━━━━┫
# ┃ 🧪 Trial Mode      ┃            ┃
# ┃ 📏 Trial Unit      ┃ Words      ┃
# ┃ 🔗 Experiment Mode ┃ Experiment ┃
# ┃ 🎭 Trial Boundary  ┃ Start      ┃
# ┃ 🔬 Trial Type      ┃ Stimulus   ┃
# ┃ 📊 Modality        ┃ Pictures   ┃
# ┃ ⏱ Tmin             ┃ -0.2       ┃
# ┃ ⏳ Tmax            ┃ 0.5        ┃
# ┗━━━━━━━━━━━━━━━━━━━━┻━━━━━━━━━━━━┛
# Not setting metadata
# 24 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 24 events and 701 original time points ...
# 0 bad epochs dropped
# [2025-11-11 14:10:06] [INFO]  Creating epochs for condition: Rest
# ╭─────────────────────────────────────╮
# │  Initializing EEGEpochBuilder Class │
# ╰─────────────────────────────────────╯
#  Creating EPOCHS
#         Extraction Criteria
# ┏━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Parameter          ┃ Value      ┃
# ┣━━━━━━━━━━━━━━━━━━━━╋━━━━━━━━━━━━┫
# ┃ 🧪 Trial Mode      ┃            ┃
# ┃ 📏 Trial Unit      ┃ Words      ┃
# ┃ 🔗 Experiment Mode ┃ Experiment ┃
# ┃ 🎭 Trial Boundary  ┃ Start      ┃
# ┃ 🔬 Trial Type      ┃ Fixation   ┃
# ┃ 📊 Modality        ┃ Pictures   ┃
# ┃ ⏱ Tmin             ┃ -0.2       ┃
# ┃ ⏳ Tmax            ┃ 0.5        ┃
# ┗━━━━━━━━━━━━━━━━━━━━┻━━━━━━━━━━━━┛
# Not setting metadata
# 24 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 24 events and 701 original time points ...
# 0 bad epochs dropped
# [2025-11-11 14:10:06] [INFO]  Epochs 1: (24, 64, 701)
# [2025-11-11 14:10:06] [INFO]  Epochs 2: (24, 64, 701)
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# [2025-11-11 14:10:06] [INFO] Running pipeline in data-only mode
# [2025-11-11 14:10:06] [INFO] Loading data for sub-09, ses-02
# [2025-11-11 14:10:06] [INFO] Initializing BIDSDatasetReader Class
# 09 02
# ╭─────────────────────────────────────────╮
# │ 🚀 Initializing BIDSDatasetReader Class │
# ╰─────────────────────────────────────────╯
# [2025-11-11 14:10:06] [INFO] Loading Processed EEG Data: sub-09 ses-02
#  Loading Processed EEG Data: sub-09 ses-02
# [2025-11-11 14:10:07] [INFO] Building epochs
# [2025-11-11 14:10:07] [INFO]  Creating epochs for condition: Visual
# ╭─────────────────────────────────────╮
# │  Initializing EEGEpochBuilder Class │
# ╰─────────────────────────────────────╯
#  Creating EPOCHS
#         Extraction Criteria
# ┏━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Parameter          ┃ Value      ┃
# ┣━━━━━━━━━━━━━━━━━━━━╋━━━━━━━━━━━━┫
# ┃ 🧪 Trial Mode      ┃            ┃
# ┃ 📏 Trial Unit      ┃ Words      ┃
# ┃ 🔗 Experiment Mode ┃ Experiment ┃
# ┃ 🎭 Trial Boundary  ┃ Start      ┃
# ┃ 🔬 Trial Type      ┃ Stimulus   ┃
# ┃ 📊 Modality        ┃ Pictures   ┃
# ┃ ⏱ Tmin             ┃ -0.2       ┃
# ┃ ⏳ Tmax            ┃ 0.5        ┃
# ┗━━━━━━━━━━━━━━━━━━━━┻━━━━━━━━━━━━┛
# Not setting metadata
# 24 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 24 events and 701 original time points ...
# 0 bad epochs dropped
# [2025-11-11 14:10:07] [INFO]  Creating epochs for condition: Rest
# ╭─────────────────────────────────────╮
# │  Initializing EEGEpochBuilder Class │
# ╰─────────────────────────────────────╯
#  Creating EPOCHS
#         Extraction Criteria
# ┏━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Parameter          ┃ Value      ┃
# ┣━━━━━━━━━━━━━━━━━━━━╋━━━━━━━━━━━━┫
# ┃ 🧪 Trial Mode      ┃            ┃
# ┃ 📏 Trial Unit      ┃ Words      ┃
# ┃ 🔗 Experiment Mode ┃ Experiment ┃
# ┃ 🎭 Trial Boundary  ┃ Start      ┃
# ┃ 🔬 Trial Type      ┃ Fixation   ┃
# ┃ 📊 Modality        ┃ Pictures   ┃
# ┃ ⏱ Tmin             ┃ -0.2       ┃
# ┃ ⏳ Tmax            ┃ 0.5        ┃
# ┗━━━━━━━━━━━━━━━━━━━━┻━━━━━━━━━━━━┛
# Not setting metadata
# 24 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 24 events and 701 original time points ...
# 0 bad epochs dropped
# [2025-11-11 14:10:08] [INFO]  Epochs 1: (24, 64, 701)
# [2025-11-11 14:10:08] [INFO]  Epochs 2: (24, 64, 701)
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 10 01
# [2025-11-11 14:10:08] [INFO] Running pipeline in data-only mode
# [2025-11-11 14:10:08] [INFO] Loading data for sub-10, ses-01
# [2025-11-11 14:10:08] [INFO] Initializing BIDSDatasetReader Class
# ╭─────────────────────────────────────────╮
# │ 🚀 Initializing BIDSDatasetReader Class │
# ╰─────────────────────────────────────────╯
# [2025-11-11 14:10:08] [INFO] Loading Processed EEG Data: sub-10 ses-01
#  Loading Processed EEG Data: sub-10 ses-01
# [2025-11-11 14:10:09] [INFO] Building epochs
# [2025-11-11 14:10:09] [INFO]  Creating epochs for condition: Visual
# ╭─────────────────────────────────────╮
# │  Initializing EEGEpochBuilder Class │
# ╰─────────────────────────────────────╯
#  Creating EPOCHS
#         Extraction Criteria
# ┏━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Parameter          ┃ Value      ┃
# ┣━━━━━━━━━━━━━━━━━━━━╋━━━━━━━━━━━━┫
# ┃ 🧪 Trial Mode      ┃            ┃
# ┃ 📏 Trial Unit      ┃ Words      ┃
# ┃ 🔗 Experiment Mode ┃ Experiment ┃
# ┃ 🎭 Trial Boundary  ┃ Start      ┃
# ┃ 🔬 Trial Type      ┃ Stimulus   ┃
# ┃ 📊 Modality        ┃ Pictures   ┃
# ┃ ⏱ Tmin             ┃ -0.2       ┃
# ┃ ⏳ Tmax            ┃ 0.5        ┃
# ┗━━━━━━━━━━━━━━━━━━━━┻━━━━━━━━━━━━┛
# Not setting metadata
# 24 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 24 events and 701 original time points ...
# 0 bad epochs dropped
# [2025-11-11 14:10:09] [INFO]  Creating epochs for condition: Rest
# ╭─────────────────────────────────────╮
# │  Initializing EEGEpochBuilder Class │
# ╰─────────────────────────────────────╯
#  Creating EPOCHS
#         Extraction Criteria
# ┏━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Parameter          ┃ Value      ┃
# ┣━━━━━━━━━━━━━━━━━━━━╋━━━━━━━━━━━━┫
# ┃ 🧪 Trial Mode      ┃            ┃
# ┃ 📏 Trial Unit      ┃ Words      ┃
# ┃ 🔗 Experiment Mode ┃ Experiment ┃
# ┃ 🎭 Trial Boundary  ┃ Start      ┃
# ┃ 🔬 Trial Type      ┃ Fixation   ┃
# ┃ 📊 Modality        ┃ Pictures   ┃
# ┃ ⏱ Tmin             ┃ -0.2       ┃
# ┃ ⏳ Tmax            ┃ 0.5        ┃
# ┗━━━━━━━━━━━━━━━━━━━━┻━━━━━━━━━━━━┛
# Not setting metadata
# 24 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 24 events and 701 original time points ...
# 0 bad epochs dropped
# [2025-11-11 14:10:09] [INFO]  Epochs 1: (24, 64, 701)
# [2025-11-11 14:10:09] [INFO]  Epochs 2: (24, 64, 701)
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# [2025-11-11 14:10:10] [INFO] Running pipeline in data-only mode
# [2025-11-11 14:10:10] [INFO] Loading data for sub-11, ses-01
# [2025-11-11 14:10:10] [INFO] Initializing BIDSDatasetReader Class
# 11 01
# ╭─────────────────────────────────────────╮
# │ 🚀 Initializing BIDSDatasetReader Class │
# ╰─────────────────────────────────────────╯
# [2025-11-11 14:10:10] [INFO] Loading Processed EEG Data: sub-11 ses-01
#  Loading Processed EEG Data: sub-11 ses-01
# [2025-11-11 14:10:11] [INFO] Building epochs
# [2025-11-11 14:10:11] [INFO]  Creating epochs for condition: Visual
# ╭─────────────────────────────────────╮
# │  Initializing EEGEpochBuilder Class │
# ╰─────────────────────────────────────╯
#  Creating EPOCHS
#         Extraction Criteria
# ┏━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Parameter          ┃ Value      ┃
# ┣━━━━━━━━━━━━━━━━━━━━╋━━━━━━━━━━━━┫
# ┃ 🧪 Trial Mode      ┃            ┃
# ┃ 📏 Trial Unit      ┃ Words      ┃
# ┃ 🔗 Experiment Mode ┃ Experiment ┃
# ┃ 🎭 Trial Boundary  ┃ Start      ┃
# ┃ 🔬 Trial Type      ┃ Stimulus   ┃
# ┃ 📊 Modality        ┃ Pictures   ┃
# ┃ ⏱ Tmin             ┃ -0.2       ┃
# ┃ ⏳ Tmax            ┃ 0.5        ┃
# ┗━━━━━━━━━━━━━━━━━━━━┻━━━━━━━━━━━━┛
# Not setting metadata
# 24 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 24 events and 701 original time points ...
# 0 bad epochs dropped
# [2025-11-11 14:10:11] [INFO]  Creating epochs for condition: Rest
# ╭─────────────────────────────────────╮
# │  Initializing EEGEpochBuilder Class │
# ╰─────────────────────────────────────╯
#  Creating EPOCHS
#         Extraction Criteria
# ┏━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Parameter          ┃ Value      ┃
# ┣━━━━━━━━━━━━━━━━━━━━╋━━━━━━━━━━━━┫
# ┃ 🧪 Trial Mode      ┃            ┃
# ┃ 📏 Trial Unit      ┃ Words      ┃
# ┃ 🔗 Experiment Mode ┃ Experiment ┃
# ┃ 🎭 Trial Boundary  ┃ Start      ┃
# ┃ 🔬 Trial Type      ┃ Fixation   ┃
# ┃ 📊 Modality        ┃ Pictures   ┃
# ┃ ⏱ Tmin             ┃ -0.2       ┃
# ┃ ⏳ Tmax            ┃ 0.5        ┃
# ┗━━━━━━━━━━━━━━━━━━━━┻━━━━━━━━━━━━┛
# Not setting metadata
# 24 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 24 events and 701 original time points ...
# 0 bad epochs dropped
# [2025-11-11 14:10:11] [INFO]  Epochs 1: (24, 64, 701)
# [2025-11-11 14:10:11] [INFO]  Epochs 2: (24, 64, 701)
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 12 01
# [2025-11-11 14:10:11] [INFO] Running pipeline in data-only mode
# [2025-11-11 14:10:11] [INFO] Loading data for sub-12, ses-01
# [2025-11-11 14:10:11] [INFO] Initializing BIDSDatasetReader Class
# ╭─────────────────────────────────────────╮
# │ 🚀 Initializing BIDSDatasetReader Class │
# ╰─────────────────────────────────────────╯
# [2025-11-11 14:10:11] [INFO] Loading Processed EEG Data: sub-12 ses-01
#  Loading Processed EEG Data: sub-12 ses-01
# [2025-11-11 14:10:13] [INFO] Building epochs
# [2025-11-11 14:10:13] [INFO]  Creating epochs for condition: Visual
# ╭─────────────────────────────────────╮
# │  Initializing EEGEpochBuilder Class │
# ╰─────────────────────────────────────╯
#  Creating EPOCHS
#         Extraction Criteria
# ┏━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Parameter          ┃ Value      ┃
# ┣━━━━━━━━━━━━━━━━━━━━╋━━━━━━━━━━━━┫
# ┃ 🧪 Trial Mode      ┃            ┃
# ┃ 📏 Trial Unit      ┃ Words      ┃
# ┃ 🔗 Experiment Mode ┃ Experiment ┃
# ┃ 🎭 Trial Boundary  ┃ Start      ┃
# ┃ 🔬 Trial Type      ┃ Stimulus   ┃
# ┃ 📊 Modality        ┃ Pictures   ┃
# ┃ ⏱ Tmin             ┃ -0.2       ┃
# ┃ ⏳ Tmax            ┃ 0.5        ┃
# ┗━━━━━━━━━━━━━━━━━━━━┻━━━━━━━━━━━━┛
# Not setting metadata
# 24 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 24 events and 701 original time points ...
# 0 bad epochs dropped
# [2025-11-11 14:10:13] [INFO]  Creating epochs for condition: Rest
# ╭─────────────────────────────────────╮
# │  Initializing EEGEpochBuilder Class │
# ╰─────────────────────────────────────╯
#  Creating EPOCHS
#         Extraction Criteria
# ┏━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Parameter          ┃ Value      ┃
# ┣━━━━━━━━━━━━━━━━━━━━╋━━━━━━━━━━━━┫
# ┃ 🧪 Trial Mode      ┃            ┃
# ┃ 📏 Trial Unit      ┃ Words      ┃
# ┃ 🔗 Experiment Mode ┃ Experiment ┃
# ┃ 🎭 Trial Boundary  ┃ Start      ┃
# ┃ 🔬 Trial Type      ┃ Fixation   ┃
# ┃ 📊 Modality        ┃ Pictures   ┃
# ┃ ⏱ Tmin             ┃ -0.2       ┃
# ┃ ⏳ Tmax            ┃ 0.5        ┃
# ┗━━━━━━━━━━━━━━━━━━━━┻━━━━━━━━━━━━┛
# Not setting metadata
# 24 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 24 events and 701 original time points ...
# 0 bad epochs dropped
# [2025-11-11 14:10:13] [INFO]  Epochs 1: (24, 64, 701)
# [2025-11-11 14:10:13] [INFO]  Epochs 2: (24, 64, 701)
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 12 02
# [2025-11-11 14:10:13] [INFO] Running pipeline in data-only mode
# [2025-11-11 14:10:13] [INFO] Loading data for sub-12, ses-02
# [2025-11-11 14:10:13] [INFO] Initializing BIDSDatasetReader Class
# ╭─────────────────────────────────────────╮
# │ 🚀 Initializing BIDSDatasetReader Class │
# ╰─────────────────────────────────────────╯
# [2025-11-11 14:10:13] [INFO] Loading Processed EEG Data: sub-12 ses-02
#  Loading Processed EEG Data: sub-12 ses-02
# [2025-11-11 14:10:15] [INFO] Building epochs
# [2025-11-11 14:10:15] [INFO]  Creating epochs for condition: Visual
# ╭─────────────────────────────────────╮
# │  Initializing EEGEpochBuilder Class │
# ╰─────────────────────────────────────╯
#  Creating EPOCHS
#         Extraction Criteria
# ┏━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Parameter          ┃ Value      ┃
# ┣━━━━━━━━━━━━━━━━━━━━╋━━━━━━━━━━━━┫
# ┃ 🧪 Trial Mode      ┃            ┃
# ┃ 📏 Trial Unit      ┃ Words      ┃
# ┃ 🔗 Experiment Mode ┃ Experiment ┃
# ┃ 🎭 Trial Boundary  ┃ Start      ┃
# ┃ 🔬 Trial Type      ┃ Stimulus   ┃
# ┃ 📊 Modality        ┃ Pictures   ┃
# ┃ ⏱ Tmin             ┃ -0.2       ┃
# ┃ ⏳ Tmax            ┃ 0.5        ┃
# ┗━━━━━━━━━━━━━━━━━━━━┻━━━━━━━━━━━━┛
# Not setting metadata
# 24 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 24 events and 701 original time points ...
# 0 bad epochs dropped
# [2025-11-11 14:10:15] [INFO]  Creating epochs for condition: Rest
# ╭─────────────────────────────────────╮
# │  Initializing EEGEpochBuilder Class │
# ╰─────────────────────────────────────╯
#  Creating EPOCHS
#         Extraction Criteria
# ┏━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Parameter          ┃ Value      ┃
# ┣━━━━━━━━━━━━━━━━━━━━╋━━━━━━━━━━━━┫
# ┃ 🧪 Trial Mode      ┃            ┃
# ┃ 📏 Trial Unit      ┃ Words      ┃
# ┃ 🔗 Experiment Mode ┃ Experiment ┃
# ┃ 🎭 Trial Boundary  ┃ Start      ┃
# ┃ 🔬 Trial Type      ┃ Fixation   ┃
# ┃ 📊 Modality        ┃ Pictures   ┃
# ┃ ⏱ Tmin             ┃ -0.2       ┃
# ┃ ⏳ Tmax            ┃ 0.5        ┃
# ┗━━━━━━━━━━━━━━━━━━━━┻━━━━━━━━━━━━┛
# Not setting metadata
# 24 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 24 events and 701 original time points ...
# 0 bad epochs dropped
# [2025-11-11 14:10:15] [INFO]  Epochs 1: (24, 64, 701)
# [2025-11-11 14:10:15] [INFO]  Epochs 2: (24, 64, 701)
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# [2025-11-11 14:10:15] [INFO] Running pipeline in data-only mode
# [2025-11-11 14:10:15] [INFO] Loading data for sub-13, ses-01
# [2025-11-11 14:10:15] [INFO] Initializing BIDSDatasetReader Class
# 13 01
# ╭─────────────────────────────────────────╮
# │ 🚀 Initializing BIDSDatasetReader Class │
# ╰─────────────────────────────────────────╯
# [2025-11-11 14:10:15] [INFO] Loading Processed EEG Data: sub-13 ses-01
#  Loading Processed EEG Data: sub-13 ses-01
# [2025-11-11 14:10:16] [INFO] Building epochs
# [2025-11-11 14:10:16] [INFO]  Creating epochs for condition: Visual
# ╭─────────────────────────────────────╮
# │  Initializing EEGEpochBuilder Class │
# ╰─────────────────────────────────────╯
#  Creating EPOCHS
#         Extraction Criteria
# ┏━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Parameter          ┃ Value      ┃
# ┣━━━━━━━━━━━━━━━━━━━━╋━━━━━━━━━━━━┫
# ┃ 🧪 Trial Mode      ┃            ┃
# ┃ 📏 Trial Unit      ┃ Words      ┃
# ┃ 🔗 Experiment Mode ┃ Experiment ┃
# ┃ 🎭 Trial Boundary  ┃ Start      ┃
# ┃ 🔬 Trial Type      ┃ Stimulus   ┃
# ┃ 📊 Modality        ┃ Pictures   ┃
# ┃ ⏱ Tmin             ┃ -0.2       ┃
# ┃ ⏳ Tmax            ┃ 0.5        ┃
# ┗━━━━━━━━━━━━━━━━━━━━┻━━━━━━━━━━━━┛
# Not setting metadata
# 24 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 24 events and 701 original time points ...
# 0 bad epochs dropped
# [2025-11-11 14:10:17] [INFO]  Creating epochs for condition: Rest
# ╭─────────────────────────────────────╮
# │  Initializing EEGEpochBuilder Class │
# ╰─────────────────────────────────────╯
#  Creating EPOCHS
#         Extraction Criteria
# ┏━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Parameter          ┃ Value      ┃
# ┣━━━━━━━━━━━━━━━━━━━━╋━━━━━━━━━━━━┫
# ┃ 🧪 Trial Mode      ┃            ┃
# ┃ 📏 Trial Unit      ┃ Words      ┃
# ┃ 🔗 Experiment Mode ┃ Experiment ┃
# ┃ 🎭 Trial Boundary  ┃ Start      ┃
# ┃ 🔬 Trial Type      ┃ Fixation   ┃
# ┃ 📊 Modality        ┃ Pictures   ┃
# ┃ ⏱ Tmin             ┃ -0.2       ┃
# ┃ ⏳ Tmax            ┃ 0.5        ┃
# ┗━━━━━━━━━━━━━━━━━━━━┻━━━━━━━━━━━━┛
# Not setting metadata
# 24 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 24 events and 701 original time points ...
# 0 bad epochs dropped
# [2025-11-11 14:10:17] [INFO]  Epochs 1: (24, 64, 701)
# [2025-11-11 14:10:17] [INFO]  Epochs 2: (24, 64, 701)
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 13 02
# [2025-11-11 14:10:17] [INFO] Running pipeline in data-only mode
# [2025-11-11 14:10:17] [INFO] Loading data for sub-13, ses-02
# [2025-11-11 14:10:17] [INFO] Initializing BIDSDatasetReader Class
# ╭─────────────────────────────────────────╮
# │ 🚀 Initializing BIDSDatasetReader Class │
# ╰─────────────────────────────────────────╯
# [2025-11-11 14:10:17] [INFO] Loading Processed EEG Data: sub-13 ses-02
#  Loading Processed EEG Data: sub-13 ses-02
# [2025-11-11 14:10:18] [INFO] Building epochs
# [2025-11-11 14:10:18] [INFO]  Creating epochs for condition: Visual
# ╭─────────────────────────────────────╮
# │  Initializing EEGEpochBuilder Class │
# ╰─────────────────────────────────────╯
#  Creating EPOCHS
#         Extraction Criteria
# ┏━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Parameter          ┃ Value      ┃
# ┣━━━━━━━━━━━━━━━━━━━━╋━━━━━━━━━━━━┫
# ┃ 🧪 Trial Mode      ┃            ┃
# ┃ 📏 Trial Unit      ┃ Words      ┃
# ┃ 🔗 Experiment Mode ┃ Experiment ┃
# ┃ 🎭 Trial Boundary  ┃ Start      ┃
# ┃ 🔬 Trial Type      ┃ Stimulus   ┃
# ┃ 📊 Modality        ┃ Pictures   ┃
# ┃ ⏱ Tmin             ┃ -0.2       ┃
# ┃ ⏳ Tmax            ┃ 0.5        ┃
# ┗━━━━━━━━━━━━━━━━━━━━┻━━━━━━━━━━━━┛
# Not setting metadata
# 24 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 24 events and 701 original time points ...
# 0 bad epochs dropped
# [2025-11-11 14:10:18] [INFO]  Creating epochs for condition: Rest
# ╭─────────────────────────────────────╮
# │  Initializing EEGEpochBuilder Class │
# ╰─────────────────────────────────────╯
#  Creating EPOCHS
#         Extraction Criteria
# ┏━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Parameter          ┃ Value      ┃
# ┣━━━━━━━━━━━━━━━━━━━━╋━━━━━━━━━━━━┫
# ┃ 🧪 Trial Mode      ┃            ┃
# ┃ 📏 Trial Unit      ┃ Words      ┃
# ┃ 🔗 Experiment Mode ┃ Experiment ┃
# ┃ 🎭 Trial Boundary  ┃ Start      ┃
# ┃ 🔬 Trial Type      ┃ Fixation   ┃
# ┃ 📊 Modality        ┃ Pictures   ┃
# ┃ ⏱ Tmin             ┃ -0.2       ┃
# ┃ ⏳ Tmax            ┃ 0.5        ┃
# ┗━━━━━━━━━━━━━━━━━━━━┻━━━━━━━━━━━━┛
# Not setting metadata
# 24 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 24 events and 701 original time points ...
# 0 bad epochs dropped
# [2025-11-11 14:10:19] [INFO]  Epochs 1: (24, 64, 701)
# [2025-11-11 14:10:19] [INFO]  Epochs 2: (24, 64, 701)
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 14 01
# [2025-11-11 14:10:19] [INFO] Running pipeline in data-only mode
# [2025-11-11 14:10:19] [INFO] Loading data for sub-14, ses-01
# [2025-11-11 14:10:19] [INFO] Initializing BIDSDatasetReader Class
# ╭─────────────────────────────────────────╮
# │ 🚀 Initializing BIDSDatasetReader Class │
# ╰─────────────────────────────────────────╯
# [2025-11-11 14:10:19] [INFO] Loading Processed EEG Data: sub-14 ses-01
#  Loading Processed EEG Data: sub-14 ses-01
# [2025-11-11 14:10:20] [INFO] Building epochs
# [2025-11-11 14:10:20] [INFO]  Creating epochs for condition: Visual
# ╭─────────────────────────────────────╮
# │  Initializing EEGEpochBuilder Class │
# ╰─────────────────────────────────────╯
#  Creating EPOCHS
#         Extraction Criteria
# ┏━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Parameter          ┃ Value      ┃
# ┣━━━━━━━━━━━━━━━━━━━━╋━━━━━━━━━━━━┫
# ┃ 🧪 Trial Mode      ┃            ┃
# ┃ 📏 Trial Unit      ┃ Words      ┃
# ┃ 🔗 Experiment Mode ┃ Experiment ┃
# ┃ 🎭 Trial Boundary  ┃ Start      ┃
# ┃ 🔬 Trial Type      ┃ Stimulus   ┃
# ┃ 📊 Modality        ┃ Pictures   ┃
# ┃ ⏱ Tmin             ┃ -0.2       ┃
# ┃ ⏳ Tmax            ┃ 0.5        ┃
# ┗━━━━━━━━━━━━━━━━━━━━┻━━━━━━━━━━━━┛
# Not setting metadata
# 24 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 24 events and 701 original time points ...
# 0 bad epochs dropped
# [2025-11-11 14:10:21] [INFO]  Creating epochs for condition: Rest
# ╭─────────────────────────────────────╮
# │  Initializing EEGEpochBuilder Class │
# ╰─────────────────────────────────────╯
#  Creating EPOCHS
#         Extraction Criteria
# ┏━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Parameter          ┃ Value      ┃
# ┣━━━━━━━━━━━━━━━━━━━━╋━━━━━━━━━━━━┫
# ┃ 🧪 Trial Mode      ┃            ┃
# ┃ 📏 Trial Unit      ┃ Words      ┃
# ┃ 🔗 Experiment Mode ┃ Experiment ┃
# ┃ 🎭 Trial Boundary  ┃ Start      ┃
# ┃ 🔬 Trial Type      ┃ Fixation   ┃
# ┃ 📊 Modality        ┃ Pictures   ┃
# ┃ ⏱ Tmin             ┃ -0.2       ┃
# ┃ ⏳ Tmax            ┃ 0.5        ┃
# ┗━━━━━━━━━━━━━━━━━━━━┻━━━━━━━━━━━━┛
# Not setting metadata
# 24 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 24 events and 701 original time points ...
# 0 bad epochs dropped
# [2025-11-11 14:10:21] [INFO]  Epochs 1: (24, 64, 701)
# [2025-11-11 14:10:21] [INFO]  Epochs 2: (24, 64, 701)
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# [2025-11-11 14:10:21] [INFO] Running pipeline in data-only mode
# [2025-11-11 14:10:21] [INFO] Loading data for sub-15, ses-01
# [2025-11-11 14:10:21] [INFO] Initializing BIDSDatasetReader Class
# 15 01
# ╭─────────────────────────────────────────╮
# │ 🚀 Initializing BIDSDatasetReader Class │
# ╰─────────────────────────────────────────╯
# [2025-11-11 14:10:21] [INFO] Loading Processed EEG Data: sub-15 ses-01
#  Loading Processed EEG Data: sub-15 ses-01
# [2025-11-11 14:10:22] [INFO] Building epochs
# [2025-11-11 14:10:22] [INFO]  Creating epochs for condition: Visual
# ╭─────────────────────────────────────╮
# │  Initializing EEGEpochBuilder Class │
# ╰─────────────────────────────────────╯
#  Creating EPOCHS
#         Extraction Criteria
# ┏━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Parameter          ┃ Value      ┃
# ┣━━━━━━━━━━━━━━━━━━━━╋━━━━━━━━━━━━┫
# ┃ 🧪 Trial Mode      ┃            ┃
# ┃ 📏 Trial Unit      ┃ Words      ┃
# ┃ 🔗 Experiment Mode ┃ Experiment ┃
# ┃ 🎭 Trial Boundary  ┃ Start      ┃
# ┃ 🔬 Trial Type      ┃ Stimulus   ┃
# ┃ 📊 Modality        ┃ Pictures   ┃
# ┃ ⏱ Tmin             ┃ -0.2       ┃
# ┃ ⏳ Tmax            ┃ 0.5        ┃
# ┗━━━━━━━━━━━━━━━━━━━━┻━━━━━━━━━━━━┛
# Not setting metadata
# 24 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 24 events and 701 original time points ...
# 0 bad epochs dropped
# [2025-11-11 14:10:22] [INFO]  Creating epochs for condition: Rest
# ╭─────────────────────────────────────╮
# │  Initializing EEGEpochBuilder Class │
# ╰─────────────────────────────────────╯
#  Creating EPOCHS
#         Extraction Criteria
# ┏━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Parameter          ┃ Value      ┃
# ┣━━━━━━━━━━━━━━━━━━━━╋━━━━━━━━━━━━┫
# ┃ 🧪 Trial Mode      ┃            ┃
# ┃ 📏 Trial Unit      ┃ Words      ┃
# ┃ 🔗 Experiment Mode ┃ Experiment ┃
# ┃ 🎭 Trial Boundary  ┃ Start      ┃
# ┃ 🔬 Trial Type      ┃ Fixation   ┃
# ┃ 📊 Modality        ┃ Pictures   ┃
# ┃ ⏱ Tmin             ┃ -0.2       ┃
# ┃ ⏳ Tmax            ┃ 0.5        ┃
# ┗━━━━━━━━━━━━━━━━━━━━┻━━━━━━━━━━━━┛
# Not setting metadata
# 24 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 24 events and 701 original time points ...
# 0 bad epochs dropped
# [2025-11-11 14:10:22] [INFO]  Epochs 1: (24, 64, 701)
# [2025-11-11 14:10:22] [INFO]  Epochs 2: (24, 64, 701)
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 15 02
# [2025-11-11 14:10:23] [INFO] Running pipeline in data-only mode
# [2025-11-11 14:10:23] [INFO] Loading data for sub-15, ses-02
# [2025-11-11 14:10:23] [INFO] Initializing BIDSDatasetReader Class
# ╭─────────────────────────────────────────╮
# │ 🚀 Initializing BIDSDatasetReader Class │
# ╰─────────────────────────────────────────╯
# [2025-11-11 14:10:23] [INFO] Loading Processed EEG Data: sub-15 ses-02
#  Loading Processed EEG Data: sub-15 ses-02
# [2025-11-11 14:10:23] [INFO] Building epochs
# [2025-11-11 14:10:23] [INFO]  Creating epochs for condition: Visual
# ╭─────────────────────────────────────╮
# │  Initializing EEGEpochBuilder Class │
# ╰─────────────────────────────────────╯
#  Creating EPOCHS
#         Extraction Criteria
# ┏━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Parameter          ┃ Value      ┃
# ┣━━━━━━━━━━━━━━━━━━━━╋━━━━━━━━━━━━┫
# ┃ 🧪 Trial Mode      ┃            ┃
# ┃ 📏 Trial Unit      ┃ Words      ┃
# ┃ 🔗 Experiment Mode ┃ Experiment ┃
# ┃ 🎭 Trial Boundary  ┃ Start      ┃
# ┃ 🔬 Trial Type      ┃ Stimulus   ┃
# ┃ 📊 Modality        ┃ Pictures   ┃
# ┃ ⏱ Tmin             ┃ -0.2       ┃
# ┃ ⏳ Tmax            ┃ 0.5        ┃
# ┗━━━━━━━━━━━━━━━━━━━━┻━━━━━━━━━━━━┛
# Not setting metadata
# 16 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 16 events and 701 original time points ...
# 0 bad epochs dropped
# [2025-11-11 14:10:23] [INFO]  Creating epochs for condition: Rest
# ╭─────────────────────────────────────╮
# │  Initializing EEGEpochBuilder Class │
# ╰─────────────────────────────────────╯
#  Creating EPOCHS
#         Extraction Criteria
# ┏━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Parameter          ┃ Value      ┃
# ┣━━━━━━━━━━━━━━━━━━━━╋━━━━━━━━━━━━┫
# ┃ 🧪 Trial Mode      ┃            ┃
# ┃ 📏 Trial Unit      ┃ Words      ┃
# ┃ 🔗 Experiment Mode ┃ Experiment ┃
# ┃ 🎭 Trial Boundary  ┃ Start      ┃
# ┃ 🔬 Trial Type      ┃ Fixation   ┃
# ┃ 📊 Modality        ┃ Pictures   ┃
# ┃ ⏱ Tmin             ┃ -0.2       ┃
# ┃ ⏳ Tmax            ┃ 0.5        ┃
# ┗━━━━━━━━━━━━━━━━━━━━┻━━━━━━━━━━━━┛
# Not setting metadata
# 16 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 16 events and 701 original time points ...
# 0 bad epochs dropped
# [2025-11-11 14:10:23] [INFO]  Epochs 1: (16, 64, 701)
# [2025-11-11 14:10:23] [INFO]  Epochs 2: (16, 64, 701)
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).

# %%
import numpy as np
visual_data = np.concatenate(visual_data, axis=0)
rest_data = np.concatenate(rest_data, axis=0)

# %%
visual_data.shape
# Out:
# (520, 3, 701)

# %%
mean_visual = visual_data.mean(axis=0).mean(axis=0)
mean_rest = rest_data.mean(axis=0).mean(axis=0)

# %%
import numpy as np
from matplotlib import pyplot as plt

# Convert from volts to microvolts
mean_visual_uv = mean_visual * 1e6
mean_rest_uv = mean_rest * 1e6

# Define time axis
n_timepoints = len(mean_visual_uv)
time = np.linspace(-0.2, 0.5, n_timepoints)

plt.figure(figsize=(10, 5))

# Plotting with stylish colors
plt.plot(time, mean_visual_uv, label='Visual', color='#1f77b4', linewidth=2.5)
plt.plot(time, mean_rest_uv, label='Rest', color='#ff7f0e', linewidth=2.5)

# Vertical line at 0
plt.axvline(0, color='k', linestyle='--', linewidth=1.5)

# Highlight 80-120 ms
plt.axvspan(0.08, 0.12, color='green', alpha=0.2, label='80-120 ms')

# Labels and title
plt.xlabel('Time (s)', fontsize=12, fontweight='bold')
plt.ylabel('Amplitude (µV)', fontsize=12, fontweight='bold')

# Grid
plt.grid(alpha=0.3, linestyle='--')

# Customize ticks
plt.xticks(np.arange(-0.2, 0.6, 0.1), fontsize=10, fontweight='bold', color='black')
plt.yticks(fontsize=10, fontweight='bold', color='black')

# Remove top and right spines
ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Legend
plt.legend(frameon=False, fontsize=12)

plt.tight_layout()
plt.show()
