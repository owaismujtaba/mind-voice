# %%
import seaborn as sns
import os
import glob
import re
import pandas as pd
from matplotlib import pyplot as plt
from src.visualizations.display_per_class_metrics import display_classwise
from src.utils.logger import create_logger

# %%
logger = create_logger('test')

# %%
display_classwise(logger)
# Out:
# [2025-11-26 17:04:17] [INFO] Class-wise precision:
# class_id
# 0    0.801227
# 1    0.735786
# 2    0.727056
# Name: precision, dtype: float64
# [2025-11-26 17:04:17] [INFO] Class-wise recall:
# class_id
# 0    0.829425
# 1    0.677286
# 2    0.661899
# Name: recall, dtype: float64
# [2025-11-26 17:04:17] [INFO] Class-wise F1 score:
# class_id
# 0    0.792203
# 1    0.675329
# 2    0.668006
# Name: f1, dtype: float64
# [2025-11-26 17:04:17] [INFO] Class-wise precision standard deviation:
# class_id
# 0    0.128688
# 1    0.144721
# 2    0.168645
# Name: precision, dtype: float64
# [2025-11-26 17:04:17] [INFO] Class-wise recall standard deviation:
# class_id
# 0    0.221939
# 1    0.228563
# 2    0.150544
# Name: recall, dtype: float64
# [2025-11-26 17:04:17] [INFO] Class-wise F1 score standard deviation:
# class_id
# 0    0.161809
# 1    0.158941
# 2    0.115190
# Name: f1, dtype: float64
