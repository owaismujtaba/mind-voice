# %%
import pandas as pd
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import ttest_rel
from glob import glob
import os
from src.utils.logger import create_logger

# %%
logger = create_logger('plotting')

# %%
from src.visualizations.peak_mean_visual_rest import plot_peak_mean_visual_novisual

# %%
plot_peak_mean_visual_novisual(logger)
# Out:
# [2025-11-20 20:34:13] [INFO] Plotting Peak and Mean amplitudes for visual and no visual conditions
# /home/owaismujtaba/projects/mind-voice/src/visualizations/peak_mean_visual_rest.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(
# /home/owaismujtaba/projects/mind-voice/src/visualizations/peak_mean_visual_rest.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(
# [2025-11-20 20:34:14] [INFO] T-test (Peak): t=-4.884, p=2.415e-04
# [2025-11-20 20:34:14] [INFO] T-test (Mean): t=-3.658, p=2.583e-03
# [2025-11-20 20:34:14] [INFO] Summary:
#  Peak -4.884, 2.415e-04,
#  Mean -3.658, 2.583e-03
# [2025-11-20 20:34:14] [INFO] Plot saved to results/images/peakMeanAmplitudeVisualRest.png

# %%
files = glob('results/P100/*.csv')
files
# Out:
# ['results/P100/sub-13_ses-01_p100_Visual_Rest.csv',
#  'results/P100/sub-06_ses-01_p100_Visual_Rest.csv',
#  'results/P100/sub-04_ses-02_p100_Visual_Rest.csv',
#  'results/P100/sub-11_ses-01_p100_Visual_Rest.csv',
#  'results/P100/sub-09_ses-01_p100_Visual_Rest.csv',
#  'results/P100/sub-02_ses-01_p100_Visual_Rest.csv',
#  'results/P100/sub-07_ses-01_p100_Visual_Rest.csv',
#  'results/P100/sub-08_ses-01_p100_Visual_Rest.csv',
#  'results/P100/sub-10_ses-01_p100_Visual_Rest.csv',
#  'results/P100/sub-15_ses-01_p100_Visual_Rest.csv',
#  'results/P100/sub-13_ses-02_p100_Visual_Rest.csv',
#  'results/P100/sub-15_ses-02_p100_Visual_Rest.csv',
#  'results/P100/sub-04_ses-01_p100_Visual_Rest.csv',
#  'results/P100/sub-06_ses-02_p100_Visual_Rest.csv',
#  'results/P100/sub-09_ses-02_p100_Visual_Rest.csv',
#  'results/P100/sub-05_ses-01_p100_Visual_Rest.csv',
#  'results/P100/sub-14_ses-01_p100_Visual_Rest.csv',
#  'results/P100/sub-01_ses-01_p100_Visual_Rest.csv',
#  'results/P100/sub-05_ses-02_p100_Visual_Rest.csv',
#  'results/P100/sub-12_ses-01_p100_Visual_Rest.csv',
#  'results/P100/sub-03_ses-01_p100_Visual_Rest.csv',
#  'results/P100/sub-12_ses-02_p100_Visual_Rest.csv']

# %%
# Load and concatenate all CSV files
all_dfs = [pd.read_csv(f) for f in files]
combined_df = pd.concat(all_dfs, ignore_index=True)

# %%
combined_df
# Out:
#     subject_id  session_id condition   latency       peak      mean
# 0           13           1    Visual  0.119141  13.015879  3.727567
# 1           13           1      Rest  0.119141  -0.130448 -2.136373
# 2            6           1    Visual  0.119141   8.188200  4.291358
# 3            6           1      Rest  0.080078  -4.133519 -5.158889
# 4            4           2    Visual  0.120000   2.827572  0.262403
# 5            4           2      Rest  0.094000   0.971232  0.345855
# 6           11           1    Visual  0.087891   2.120805  0.954290
# 7           11           1      Rest  0.114258   1.577679  0.573276
# 8            9           1    Visual  0.119141   7.176051  1.573540
# 9            9           1      Rest  0.119141  -0.225202 -2.111791
# 10           2           1    Visual  0.119141   4.754809  0.889601
# 11           2           1      Rest  0.119141   0.993780 -2.168375
# 12           7           1    Visual  0.119141   4.753132  0.828544
# 13           7           1      Rest  0.104492  -0.851082 -1.155975
# 14           8           1    Visual  0.119141  13.914869  7.563942
# 15           8           1      Rest  0.119141   2.538145  1.098210
# 16          10           1    Visual  0.119141   8.392448  3.607370
# 17          10           1      Rest  0.119141   2.137212  0.484439
# 18          15           1    Visual  0.119141   2.115118 -0.981204
# 19          15           1      Rest  0.104492   2.119051  1.039776
# 20          13           2    Visual  0.120000  14.342258  4.659451
# 21          13           2      Rest  0.120000   0.632168 -3.060807
# 22          15           2    Visual  0.120000   4.088828  0.422805
# 23          15           2      Rest  0.080000  -1.282099 -3.685700
# 24           4           1    Visual  0.119141   4.740616  1.723291
# 25           4           1      Rest  0.110352   2.256635  1.068372
# 26           6           2    Visual  0.120000  11.148589  4.992571
# 27           6           2      Rest  0.086000   0.054085 -1.227938
# 28           9           2    Visual  0.120000   4.311655  0.755530
# 29           9           2      Rest  0.120000   2.092298  1.121593
# 30           5           1    Visual  0.119141   1.363510 -0.944330
# 31           5           1      Rest  0.119141   1.310618 -0.319500
# 32          14           1    Visual  0.119141   4.779331 -0.754596
# 33          14           1      Rest  0.100586   0.358739 -0.191140
# 34           1           1    Visual  0.114258   2.859323  0.095797
# 35           1           1      Rest  0.095703   0.969238 -0.636067
# 36           5           2    Visual  0.120000   7.244820  5.356719
# 37           5           2      Rest  0.080000  -5.293928 -6.827225
# 38          12           1    Visual  0.119141   2.678504  0.838363
# 39          12           1      Rest  0.119141   3.169604  2.000788
# 40           3           1    Visual  0.109375   4.300213  2.469350
# 41           3           1      Rest  0.080078   0.626569 -1.458880
# 42          12           2    Visual  0.116000   5.838567  2.981537
# 43          12           2      Rest  0.120000   6.610112  4.956703

# %%
gp_df = combined_df.groupby(by=['subject_id', 'condition']).mean().reset_index()
gp_df
# Out:
#     subject_id condition  session_id   latency       peak      mean
# 0            1      Rest         1.0  0.095703   0.969238 -0.636067
# 1            1    Visual         1.0  0.114258   2.859323  0.095797
# 2            2      Rest         1.0  0.119141   0.993780 -2.168375
# 3            2    Visual         1.0  0.119141   4.754809  0.889601
# 4            3      Rest         1.0  0.080078   0.626569 -1.458880
# 5            3    Visual         1.0  0.109375   4.300213  2.469350
# 6            4      Rest         1.5  0.102176   1.613934  0.707113
# 7            4    Visual         1.5  0.119570   3.784094  0.992847
# 8            5      Rest         1.5  0.099570  -1.991655 -3.573363
# 9            5    Visual         1.5  0.119570   4.304165  2.206194
# 10           6      Rest         1.5  0.083039  -2.039717 -3.193413
# 11           6    Visual         1.5  0.119570   9.668395  4.641964
# 12           7      Rest         1.0  0.104492  -0.851082 -1.155975
# 13           7    Visual         1.0  0.119141   4.753132  0.828544
# 14           8      Rest         1.0  0.119141   2.538145  1.098210
# 15           8    Visual         1.0  0.119141  13.914869  7.563942
# 16           9      Rest         1.5  0.119570   0.933548 -0.495099
# 17           9    Visual         1.5  0.119570   5.743853  1.164535
# 18          10      Rest         1.0  0.119141   2.137212  0.484439
# 19          10    Visual         1.0  0.119141   8.392448  3.607370
# 20          11      Rest         1.0  0.114258   1.577679  0.573276
# 21          11    Visual         1.0  0.087891   2.120805  0.954290
# 22          12      Rest         1.5  0.119570   4.889858  3.478745
# 23          12    Visual         1.5  0.117570   4.258536  1.909950
# 24          13      Rest         1.5  0.119570   0.250860 -2.598590
# 25          13    Visual         1.5  0.119570  13.679069  4.193509
# 26          14      Rest         1.0  0.100586   0.358739 -0.191140
# 27          14    Visual         1.0  0.119141   4.779331 -0.754596
# 28          15      Rest         1.5  0.092246   0.418476 -1.322962
# 29          15    Visual         1.5  0.119570   3.101973 -0.279199

# %%
no_visual = gp_df[gp_df['condition']=='Rest']
no_visual.describe()
# Out:
#        subject_id  session_id    latency       peak       mean
# count   15.000000   15.000000  15.000000  15.000000  15.000000
# mean     8.000000    1.233333   0.105885   0.828372  -0.696805
# std      4.472136    0.258199   0.013940   1.734745   1.840233
# min      1.000000    1.000000   0.080078  -2.039717  -3.573363
# 25%      4.500000    1.000000   0.097637   0.304799  -1.813627
# 50%      8.000000    1.000000   0.104492   0.933548  -0.636067
# 75%     11.500000    1.500000   0.119141   1.595806   0.528857
# max     15.000000    1.500000   0.119570   4.889858   3.478745

# %%
visual = gp_df[gp_df['condition']=='Visual']
visual.describe()
# Out:
#        subject_id  session_id    latency       peak       mean
# count   15.000000   15.000000  15.000000  15.000000  15.000000
# mean     8.000000    1.233333   0.116148   6.027668   2.032273
# std      4.472136    0.258199   0.008302   3.707735   2.194271
# min      1.000000    1.000000   0.087891   2.120805  -0.754596
# 25%      4.500000    1.000000   0.118355   4.021315   0.859072
# 50%      8.000000    1.000000   0.119141   4.753132   1.164535
# 75%     11.500000    1.500000   0.119570   7.068151   3.038360
# max     15.000000    1.500000   0.119570  13.914869   7.563942
