# %%
import pandas as pd

# %%
path = 'BIDS/sub-01/ses-01/eeg/sub-01_ses-01_task-VCV_run-01_events.tsv'

# %%
data = pd.read_csv(path, delimiter='\t')

# %%
trials = data['trial_type'].values

# %%
trails = [t for t in types if 'Experiment' in t and 'Start' in t and 'ITI' not in t and 'Fixation' not in t and 'ISI' not in t]
trials[:5]
# Out:
# array(['SilentSyllablesPracticeStartFixation:Text_FAS',
#        'SilentSyllablesPracticeEndFixation:Text_FAS',
#        'SilentSyllablesPracticeStartStimulus:Text_FAS',
#        'SilentSyllablesPracticeEndStimulus:Text_FAS',
#        'SilentSyllablesPracticeStartISI:Text_FAS'], dtype=object)

# %%
modilites = {'Text':0, 'Audio':0, 'Pictures':0}
st = {'Stimulus':0, 'Speech':0}
for t in trails:
    mod = t.split(':')[1].split('_')[0]
    modilites[mod] += 1

# %%
modilites
# Out:
# {'Text': 780, 'Audio': 780, 'Pictures': 260}

# %%
mod
# Out:
# 'Text'

# %%
import mne

# %%
data = mne.io.read_raw_edf('BIDS/sub-01/ses-01/eeg/sub-01_ses-01_task-VCV_run-01_eeg.edf')
# Out:
# Extracting EDF parameters from /home/owaismujtaba/projects/mind-voice/BIDS/sub-01/ses-01/eeg/sub-01_ses-01_task-VCV_run-01_eeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...

# %%
data
# Out:
# <RawEDF | sub-01_ses-01_task-VCV_run-01_eeg.edf, 64 x 6307000 (6307.0 s), ~65 KiB, data not loaded>

# %%
6307/60
# Out:
# 105.11666666666666
