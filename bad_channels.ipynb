# %%
import os
import json
from glob import glob
import pandas as pd
from pathlib import Path

# %%
folder = '/home/owaismujtaba/projects/mind-voice/results/ica'

# %%
files = glob(os.path.join(folder, '*.json'))
files
# Out:
# ['/home/owaismujtaba/projects/mind-voice/results/ica/sub-06_ses-01_bad_channels.json',
#  '/home/owaismujtaba/projects/mind-voice/results/ica/sub-04_ses-02_bad_channels.json',
#  '/home/owaismujtaba/projects/mind-voice/results/ica/sub-08_ses-01_bad_channels.json',
#  '/home/owaismujtaba/projects/mind-voice/results/ica/sub-13_ses-01_bad_channels.json',
#  '/home/owaismujtaba/projects/mind-voice/results/ica/sub-15_ses-02_bad_channels.json',
#  '/home/owaismujtaba/projects/mind-voice/results/ica/sub-12_ses-02_bad_channels.json',
#  '/home/owaismujtaba/projects/mind-voice/results/ica/sub-03_ses-01_bad_channels.json',
#  '/home/owaismujtaba/projects/mind-voice/results/ica/sub-13_ses-02_bad_channels.json',
#  '/home/owaismujtaba/projects/mind-voice/results/ica/sub-10_ses-01_bad_channels.json',
#  '/home/owaismujtaba/projects/mind-voice/results/ica/sub-02_ses-01_bad_channels.json',
#  '/home/owaismujtaba/projects/mind-voice/results/ica/sub-15_ses-01_bad_channels.json',
#  '/home/owaismujtaba/projects/mind-voice/results/ica/sub-01_ses-01_bad_channels.json',
#  '/home/owaismujtaba/projects/mind-voice/results/ica/sub-14_ses-01_bad_channels.json',
#  '/home/owaismujtaba/projects/mind-voice/results/ica/sub-07_ses-01_bad_channels.json',
#  '/home/owaismujtaba/projects/mind-voice/results/ica/sub-04_ses-01_bad_channels.json',
#  '/home/owaismujtaba/projects/mind-voice/results/ica/sub-09_ses-01_bad_channels.json',
#  '/home/owaismujtaba/projects/mind-voice/results/ica/sub-05_ses-02_bad_channels.json',
#  '/home/owaismujtaba/projects/mind-voice/results/ica/sub-11_ses-01_bad_channels.json',
#  '/home/owaismujtaba/projects/mind-voice/results/ica/sub-06_ses-02_bad_channels.json',
#  '/home/owaismujtaba/projects/mind-voice/results/ica/sub-05_ses-01_bad_channels.json',
#  '/home/owaismujtaba/projects/mind-voice/results/ica/sub-12_ses-01_bad_channels.json',
#  '/home/owaismujtaba/projects/mind-voice/results/ica/sub-09_ses-02_bad_channels.json']

# %%
subjects, sessions, bad_channels = [], [], []
for file in files:
    with open(file, 'r') as f:
        data = json.load(f)
    subject_id = Path(file).stem.split('_')[0]
    session_id = Path(file).stem.split('_')[1]
    subjects.append(subject_id)
    sessions.append(session_id)
    bad_channels.append(len(data))

# %%
data = pd
# Out:
# 4
